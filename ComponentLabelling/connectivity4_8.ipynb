# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a=[[0,1,1,1],[0,0,1,1],[1,0,1,0],[1,1,0,1]]
a=np.array(a)
n=a.shape[0]

# %%
plt.imshow(a,cmap = plt.get_cmap('gray'),extent=[0,n,0,n])
plt.xticks(np.arange(0, n+1, 1))
plt.yticks(np.arange(0, n+1, 1))
plt.grid()
plt.show()

# %%
for i in range(n):
    for j in range(n):
        if a[i][j]==1:
            f=a.copy()
            f[i][j]=10
            print("4-connected components of (",i,",",j,") are")
            if i-1>=0 and a[i-1][j]==1:
                f[i-1][j]=8
                print("(",i-1,",",j,")")
            if i+1<n and a[i+1][j]==1:
                f[i+1][j]=8
                print("(",i+1,",",j,")")
            if j-1>=0 and a[i][j-1]==1:
                print("(",i,",",j-1,")")
                f[i][j-1]=8
            if j+1<n and a[i][j+1]==1:
                print("(",i,",",j+1,")")
                f[i][j+1]=8
            print(f)
            plt.clf()
            plt.imshow(f,extent=[0,n,0,n])
            plt.xticks(np.arange(0, n+1, 1))
            plt.yticks(np.arange(0, n+1, 1))
            plt.grid()
            plt.show()
# Out:
# 4-connected components of ( 0 , 1 ) are
# ( 0 , 2 )
# [[ 0 10  8  1]
#  [ 0  0  1  1]
#  [ 1  0  1  0]
#  [ 1  1  0  1]]
# 4-connected components of ( 0 , 2 ) are
# ( 1 , 2 )
# ( 0 , 1 )
# ( 0 , 3 )
# [[ 0  8 10  8]
#  [ 0  0  8  1]
#  [ 1  0  1  0]
#  [ 1  1  0  1]]
# 4-connected components of ( 0 , 3 ) are
# ( 1 , 3 )
# ( 0 , 2 )
# [[ 0  1  8 10]
#  [ 0  0  1  8]
#  [ 1  0  1  0]
#  [ 1  1  0  1]]
# 4-connected components of ( 1 , 2 ) are
# ( 0 , 2 )
# ( 2 , 2 )
# ( 1 , 3 )
# [[ 0  1  8  1]
#  [ 0  0 10  8]
#  [ 1  0  8  0]
#  [ 1  1  0  1]]
# 4-connected components of ( 1 , 3 ) are
# ( 0 , 3 )
# ( 1 , 2 )
# [[ 0  1  1  8]
#  [ 0  0  8 10]
#  [ 1  0  1  0]
#  [ 1  1  0  1]]
# 4-connected components of ( 2 , 0 ) are
# ( 3 , 0 )
# [[ 0  1  1  1]
#  [ 0  0  1  1]
#  [10  0  1  0]
#  [ 8  1  0  1]]
# 4-connected components of ( 2 , 2 ) are
# ( 1 , 2 )
# [[ 0  1  1  1]
#  [ 0  0  8  1]
#  [ 1  0 10  0]
#  [ 1  1  0  1]]
# 4-connected components of ( 3 , 0 ) are
# ( 2 , 0 )
# ( 3 , 1 )
# [[ 0  1  1  1]
#  [ 0  0  1  1]
#  [ 8  0  1  0]
#  [10  8  0  1]]
# 4-connected components of ( 3 , 1 ) are
# ( 3 , 0 )
# [[ 0  1  1  1]
#  [ 0  0  1  1]
#  [ 1  0  1  0]
#  [ 8 10  0  1]]
# 4-connected components of ( 3 , 3 ) are
# [[ 0  1  1  1]
#  [ 0  0  1  1]
#  [ 1  0  1  0]
#  [ 1  1  0 10]]

# %%
for i in range(n):
    for j in range (n):
        if a[i][j]==1:
            f=a.copy()
            f[i][j]=10
            print("8-connected components of (",i,",",j,") are")
            if i-1>=0 and a[i-1][j]==1:
                f[i-1][j]=8
                print("(",i-1,",",j,")")
            if i+1<n and a[i+1][j]==1:
                f[i+1][j]=8
                print("(",i+1,",",j,")")
            if j-1>=0 and a[i][j-1]==1:
                f[i][j-1]=8
                print("(",i,",",j-1,")")
            if j+1<n and a[i][j+1]==1:
                f[i][j+1]=8
                print("(",i,",",j+1,")")
            if i-1>=0 and j-1>=0 and a[i-1][j-1]==1:
                f[i-1][j-1]=8
                print("(",i-1,",",j-1,")")
            if i+1<n and j+1<n and a[i+1][j+1]==1:
                f[i+1][j+1]=8
                print("(",i+1,",",j+1,")")
            if j-1>=0 and i+1<n and a[i+1][j-1]==1:
                f[i+1][j-1]=8
                print("(",i+1,",",j-1,")")
            if j+1<n and i-1>=0 and a[i-1][j+1]==1:
                f[i-1][j+1]=8
                print("(",i-1,",",j+1,")")
            plt.clf()
            plt.imshow(f,extent=[0,n,0,n])
            plt.xticks(np.arange(0, n+1, 1))
            plt.yticks(np.arange(0, n+1, 1))
            plt.grid()
            plt.show()
# Out:
# 8-connected components of ( 0 , 1 ) are
# ( 0 , 2 )
# ( 1 , 2 )
# 8-connected components of ( 0 , 2 ) are
# ( 1 , 2 )
# ( 0 , 1 )
# ( 0 , 3 )
# ( 1 , 3 )
# 8-connected components of ( 0 , 3 ) are
# ( 1 , 3 )
# ( 0 , 2 )
# ( 1 , 2 )
# 8-connected components of ( 1 , 2 ) are
# ( 0 , 2 )
# ( 2 , 2 )
# ( 1 , 3 )
# ( 0 , 1 )
# ( 0 , 3 )
# 8-connected components of ( 1 , 3 ) are
# ( 0 , 3 )
# ( 1 , 2 )
# ( 0 , 2 )
# ( 2 , 2 )
# 8-connected components of ( 2 , 0 ) are
# ( 3 , 0 )
# ( 3 , 1 )
# 8-connected components of ( 2 , 2 ) are
# ( 1 , 2 )
# ( 3 , 3 )
# ( 3 , 1 )
# ( 1 , 3 )
# 8-connected components of ( 3 , 0 ) are
# ( 2 , 0 )
# ( 3 , 1 )
# 8-connected components of ( 3 , 1 ) are
# ( 3 , 0 )
# ( 2 , 0 )
# ( 2 , 2 )
# 8-connected components of ( 3 , 3 ) are
# ( 2 , 2 )
