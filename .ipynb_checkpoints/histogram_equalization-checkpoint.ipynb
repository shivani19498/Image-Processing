# %%
import cv2 
import matplotlib.pyplot as plt
import numpy as np 
  
img = cv2.imread('HistEq.PNG', 0) 
print(img)
plt.imshow(img)
plt.show()
# Out:
# [[84 85 85 ... 93 93 93]
#  [84 84 84 ... 93 93 93]
#  [83 84 84 ... 93 93 93]
#  ...
#  [58 58 58 ... 74 74 74]
#  [58 58 58 ... 74 74 74]
#  [58 58 58 ... 74 74 74]]

# %%
equ = cv2.equalizeHist(img) 
#res = np.hstack((img, equ)) 
print(equ)
plt.imshow(equ)
plt.show()
# Out:
# [[ 50  60  60 ... 169 169 169]
#  [ 50  50  50 ... 169 169 169]
#  [ 42  50  50 ... 169 169 169]
#  ...
#  [  1   1   1 ...   7   7   7]
#  [  1   1   1 ...   7   7   7]
#  [  1   1   1 ...   7   7   7]]
